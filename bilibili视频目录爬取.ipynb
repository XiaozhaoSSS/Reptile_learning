# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.bilibili.com/video/av30708793/'
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'}
headers = {
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,ja;q=0.7',
        'Connection': 'keep-alive',
        'Origin': 'https://www.bilibili.com',
        # 'Referer': 'https://www.bilibili.com/video/' + str(i) + '?spm_id_from=333.338.recommend_report.3',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
    }
raw_cookies="rpdid=|(JJmY~l|kkY0J'ull)|)ulYl; buvid3=C8233F30-6267-43DD-971F-CEB543D2B2AD110267infoc; UM_distinctid=16ac5c1e99585a-05d0b8351e8df-3d644509-1fa400-16ac5c1e996acc; _uuid=45C11606-833D-8F23-FC4D-3648C0EC8DE603087infoc; LIVE_BUVID=AUTO1215611110902153; CURRENT_FNVAL=16; stardustvideo=1; _uuid=33C85F4E-0186-B642-D9D3-34740A2BF04107439infoc; fts=1566980644; sid=8c716bpu; DedeUserID=409495891; DedeUserID__ckMd5=ae2fc4fc7c416a89; SESSDATA=a17f7e20%2C1572077751%2Cee5ff791; bili_jct=0c64b504819b8bc99a7e10ce921953cc"
cookies = {}
for line in raw_cookies.split(';'):
    key, value = line.split('=', 1)
    cookies[key] = value

r=requests.get(url,timeout=15,cookies=cookies,headers =headers)
print(r.status_code)
r.raise_for_status
r.encoding=r.apparent_encoding

soup=BeautifulSoup(r.text,'lxml')
print(soup.find('div',id='playerWrap'))
print(soup.find_all('li',class_='bilibili-player-video-btn-menu-list '))
list_box=soup.find('ul',class_='bilibili-player-video-btn-menu')
print(list_box)
mulus=list_box.find_all('li')
for mulu in mulus:
    curr=mulu.text
    with open('目录.txt','a+') as f:
        f.write(curr,'\n')
# Out:
# 200
# <div class="player-wrap" id="playerWrap"><div id="bofqi"></div><div><script type="text/javascript">
#         setSize()
#
#         function gqs(name) {
#           var reg = new RegExp("(^|&)" + name + "=([^&]*)(&|$)");
#           var r = window.location.search.substr(1).match(reg);
#           if (r != null) {
#             return unescape(r[2])
#           }
#           return null
#         }
#
#         function getCookie(name) {
#           var reg = new RegExp("(^| )"+name+"=([^;]*)(;|$)")
#           var r = document.cookie.match(reg)
#           return r ? unescape(r[2]) : null
#         }
#
#         var vd = window.__INITIAL_STATE__ && window.__INITIAL_STATE__.videoData
#         if(vd && vd.aid) {
#           if(vd.embedPlayer) {
#             var fp = gqs('p') || gqs('page') || null
#             var p = fp ? fp - 1 : 0
#             var player = {
#               aid: vd.aid,
#               cid: (vd.pages[p] && vd.pages[p].cid) || vd.pages[0].cid,
#               attribute: vd.attribute
#             }
#             EmbedPlayer("player", "//static.hdslb.com/play.swf", "cid=" + player.cid + "&aid=" + player.aid + "&attribute=" + player.attribute)
#           }else if(vd.embed) {
#             document.querySelector("#bofqi").innerHTML = vd.embed
#           }
#         }
#       </script></div></div>
# []
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-7065b938855e> in <module>
#      25 list_box=soup.find('ul',class_='bilibili-player-video-btn-menu')
#      26 print(list_box)
# ---> 27 mulus=list_box.find_all('li')
#      28 for mulu in mulus:
#      29     curr=mulu.text
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# # 扒下来的内容是空的，把soup转成字符搜索

# %%
headers = {
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,ja;q=0.7',
        'Connection': 'keep-alive',
        # 'Referer': 'https://www.bilibili.com/video/' + str(i) + '?spm_id_from=333.338.recommend_report.3',
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
    }
content=requests.get('https://www.bilibili.com/video/av30708793/', headers=headers, timeout=6).text
content
# Out:
# '<!DOCTYPE html><html><head itemprop="video" itemscope itemtype="http://schema.org/VideoObject"><title data-vue-meta="true">清华 操作系统原理_哔哩哔哩 (゜-゜)つロ 干杯~-bilibili</title> <meta data-vue-meta="true" http-equiv="Content-Type" content="text/html" charset="utf-8"><meta data-vue-meta="true" name="renderer" content="webkit"><meta data-vue-meta="true" http-equiv="X-UA-Compatible" content="IE=edge"><meta data-vue-meta="true" name="spm_prefix" content="333.788"><meta data-vue-meta="true" itemprop="keywords" name="keywords" content="清华 操作系统原理,清华大学,操作系统原理,学习,科技,演讲·公开课,哔哩哔哩,Bilibili,B站,弹幕"><meta data-vue-meta="true" itemprop="description" name="description" content="清华 操作系统原理"><meta data-vue-meta="true" itemprop="author" name="author" content="骄傲的魂灵"><meta data-vue-meta="true" itemprop="name" name="title" content="清华 操作系统原理_哔哩哔哩 (゜-゜)つロ 干杯~-bilibili"><meta data-vue-meta="true" itemprop="url" content="https://www.bilibili.com/video/av30708793/"><meta data-vue-meta="true" itemprop="image" content="http://i0.hdslb.com/bfs/archive/14dc2994d549467c378dffe704b8de0dd50efdc0.jpg"><meta data-vue-meta="true" itemprop="thumbnailUrl" content="http://i0.hdslb.com/bfs/archive/14dc2994d549467c378dffe704b8de0dd50efdc0.jpg"><meta data-vue-meta="true" itemprop="uploadDate" content="2018-08-30 16:41:47"><meta data-vue-meta="true" itemprop="datePublished" content="2018-08-30 16:41:43"><meta data-vue-meta="true" itemprop="comment" content="配套上机实验地址：https://www.shiyanlou.com/courses/221github上的课程项目：https://github.com/chyyuu/os_course_info,7.11跟7.12的内容重复了，创建进程的那个课件应该是丢了,看了三节课，做了很多笔记，听不懂，觉得自己在虐待自己"><meta data-vue-meta="true" itemprop="commentCount" content="41"><meta data-vue-meta="true" property="og:type" content="video"><meta data-vue-meta="true" property="og:title" content="清华 操作系统原理_哔哩哔哩 (゜-゜)つロ 干杯~-bilibili"><meta data-vue-meta="true" property="og:image" content="http://i0.hdslb.com/bfs/archive/14dc2994d549467c378dffe704b8de0dd50efdc0.jpg"><meta data-vue-meta="true" property="og:url" content="https://www.bilibili.com/video/av30708793/"><meta data-vue-meta="true" property="og:width" content="846"><meta data-vue-meta="true" property="og:height" content="566"> <link data-vue-meta="true" rel="canonical" href="https://www.bilibili.com/video/av30708793/"><script type="text/javascript">!function(){for(var o=window.navigator.userAgent,i=["Android","iPhone","SymbianOS","Windows Phone","iPod"],r=!0,a=0,n=i.length;a<n;a++)if(0<o.indexOf(i[a])){r=!1;break}if(!r){var e=window.location.origin.replace("www","m")+"/video/"+window.location.href.match(/av([0-9]+)/g)[0]+".html"+window.location.search;window.location.href=e}}(),window.spmReportData={},window.reportConfig={sample:1,scrollTracker:!0,msgObjects:"spmReportData",errorTracker:!0,hasAbtest:!0,abtestPlatform:4}</script><style>.ie-fix{background:#fff;position:fixed;left:0;top:0;right:0;bottom:0;width:100%;height:100%;z-index:9999999}.ie-fix .title{background:#00a1d6;text-align:center;padding:10px 0;color:#fff}</style><script>window.__playinfo__={"code":0,"message":"0","ttl":1,"data":{"from":"local","result":"suee","message":"","quality":32,"format":"flv480","timelength":371708,"accept_format":"flv480,flv360","accept_description":["清晰 480P","流畅 360P"],"accept_quality":[32,16],"video_codecid":7,"seek_param":"start","seek_type":"offset","dash":{"duration":372,"minBufferTime":1.5,"min_buffer_time":1.5,"video":[{"id":32,"baseUrl":"http://upos-hz-mirrorkodou.acgvideo.com/upgcxcode/02/66/53736602/53736602-1-30032.m4s?e=ig8euxZM2rNcNbdlhoNvNC8BqJIzNbfqXBvEqxTEto8BTrNvN0GvT90W5JZMkX_YN0MvXg8gNEV4NC8xNEV4N03eN0B5tZlqNxTEto8BTrNvNeZVuJ10Kj_g2UB02J0mN0B5tZlqNCNEto8BTrNvNC7MTX502C8f2jmMQJ6mqF2fka1mqx6gqj0eN0B599M=&uipk=5&nbs=1&deadline=1569495106&gen=playurl&os=kodou&oi=3396750226&trid=323b54be2775498981ca21ef997654ddu&platform=pc&upsig=f91c60b41a0866b8b6ff50ec5cdab0b8&uparams=e,uipk,nbs,deadline,gen,os,oi,trid,platform&mid=0","base_url":"http://upos-hz-mirrorkodou.acgvideo.com/upgcxcode/02/66/53736602/53736602-1-30032.m4s?e=ig8euxZM2 ...

# %%
import re

# %%
content_list=content.split('"part"')
mululist=[x for x in content_list if re.match(r'(.*)"duration"(.*),"vid":"","weblink":"","dimension":',x)]

# %%
mululist
# Out:
# [':"1.1 课程概述","duration":372,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736604,"page":2,"from":"vupload",',
#  ':"1.2 什么是操作系统","duration":976,"vid":"","weblink":"","dimension":{"width":1280,"height":960,"rotate":0}},{"cid":53736625,"page":3,"from":"vupload",',
#  ':"1.2 什么是操作系统","duration":965,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736658,"page":4,"from":"vupload",',
#  ':"1.2 什么是操作系统","duration":965,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736695,"page":5,"from":"vupload",',
#  ':"1.3 为什么学习操作系统","duration":987,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736802,"page":6,"from":"vupload",',
#  ':"1.4 如何学习操作系统","duration":117,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736843,"page":7,"from":"vupload",',
#  ':"1.5 操作系统实例","duration":333,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736849,"page":8,"from":"vupload",',
#  ':"1.6 操作系统的历史","duration":687,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736869,"page":9,"from":"vupload",',
#  ':"1.7 操作系统结构","duration":617,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736912,"page":10,"from":"vupload",',
#  ':"1.8 小结","duration":89,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736950,"page":11,"from":"vupload",',
#  ':"2.1 操作系统的启动","duration":1157,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53736956,"page":12,"from":"vupload",',
#  ':"2.2 操作系统的终端、异常、和系统调用","duration":1042,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53737011,"page":13,"from":"vupload",',
#  ':"3.1 计算机体系结构及内存分层体系","duration":627,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53737098,"page":14,"from":"vupload",',
#  ':"3.2 地址空间与地址生成","duration":686,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53737137,"page":15,"from":"vupload",',
#  ':"3.3 连续内存分配：内存碎片与分区的动态分配","duration":735,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53737170,"page":16,"from":"vupload",',
#  ':"3.4 连续内存分配：压缩式与交换式碎片整理","duration":610,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53737213,"page":17,"from":"vupload",',
#  ':"4.1 非连续内存分配：分段","duration":763,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737233,"page":18,"from":"vupload",',
#  ':"4.2 非连续内存分配：分页","duration":729,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737281,"page":19,"from":"vupload",',
#  ':"4.3 非连续内存分配：页表－概述、TLB","duration":886,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737321,"page":20,"from":"vupload",',
#  ':"4.4 非连续内存分配：页表－二级，多级页表","duration":345,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737429,"page":21,"from":"vupload",',
#  ':"4.5 非连续内存分配：页表－反向页表","duration":714,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737584,"page":22,"from":"vupload",',
#  ':"5.1 虚拟内存的起因","duration":674,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737667,"page":23,"from":"vupload",',
#  ':"5.2 覆盖技术","duration":661,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737734,"page":24,"from":"vupload",',
#  ':"5.3 交换技术","duration":551,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737756,"page":25,"from":"vupload",',
#  ':"5.4 虚存技术（上）","duration":1365,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737774,"page":26,"from":"vupload",',
#  ':"5.5 虚存技术（下）","duration":1309,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737825,"page":27,"from":"vupload",',
#  ':"6.1 最优页面置换算法","duration":621,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737858,"page":28,"from":"vupload",',
#  ':"6.2 先进先出算法","duration":324,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737881,"page":29,"from":"vupload",',
#  ':"6.3 最近最久未使用算法","duration":714,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737901,"page":30,"from":"vupload",',
#  ':"6.4 时钟页面置换算法","duration":907,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737950,"page":31,"from":"vupload",',
#  ':"6.5 二次机会法","duration":702,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53737994,"page":32,"from":"vupload",',
#  ':"6.6 最不常用法","duration":332,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738035,"page":33,"from":"vupload",',
#  ':"6.7 Belady现象、LRU、FIFO、Clock的比较","duration":862,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738064,"page":34,"from":"vupload",',
#  ':"6.8 局部页替换算法的问题、工作集模型","duration":750,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738186,"page":35,"from":"vupload",',
#  ':"6.9 两个全局置换算法","duration":1139,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738266,"page":36,"from":"vupload",',
#  ':"6.10 抖动问题","duration":495,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738326,"page":37,"from":"vupload",',
#  ':"7.1 进程的定义","duration":299,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738360,"page":38,"from":"vupload",',
#  ':"7.2 进程的组成","duration":586,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738400,"page":39,"from":"vupload",',
#  ':"7.3 进程的特点","duration":416,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738454,"page":40,"from":"vupload",',
#  ':"7.4 进程控制结构","duration":436,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738489,"page":41,"from":"vupload",',
#  ':"7.5 进程的生命期原理","duration":434,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738533,"page":42,"from":"vupload",',
#  ':"7.6 进程状态变化模型","duration":429,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738634,"page":43,"from":"vupload",',
#  ':"7.7 进程挂起","duration":589,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738681,"page":44,"from":"vupload",',
#  ':"7.8 为什么使用线程","duration":324,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738758,"page":45,"from":"vupload",',
#  ':"7.9 什么是线程","duration":733,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738806,"page":46,"from":"vupload",',
#  ':"7.10 线程的实现","duration":547,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53738936,"page":47,"from":"vupload",',
#  ':"7.11 上下文切换","duration":293,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739012,"page":48,"from":"vupload",',
#  ':"7.12 进程控制——创建进程","duration":293,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739036,"page":49,"from":"vupload",',
#  ':"7.13 进程控制——加载和执行进程","duration":683,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739057,"page":50,"from":"vupload",',
#  ':"7.14 进程控制——等待和终止进程","duration":593,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739130,"page":51,"from":"vupload",',
#  ':"8.1 背景","duration":448,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739189,"page":52,"from":"vupload",',
#  ':"8.2 调度原则","duration":780,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739217,"page":53,"from":"vupload",',
#  ':"8.3 调度算法1","duration":1190,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739284,"page":54,"from":"vupload",',
#  ':"8.4 调度算法2","duration":1028,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739417,"page":55,"from":"vupload",',
#  ':"8.5 实时调度","duration":523,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739518,"page":56,"from":"vupload",',
#  ':"8.6 多处理器调度与优先级反转","duration":518,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739568,"page":57,"from":"vupload",',
#  ':"9.1 背景知识","duration":782,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739609,"page":58,"from":"vupload",',
#  ':"9.2 一些概念part1","duration":418,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739673,"page":59,"from":"vupload",',
#  ':"9.3 一些概念part2","duration":755,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739688,"page":60,"from":"vupload",',
#  ':"9.4 一些概念part3","duration":677,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739762,"page":61,"from":"vupload",',
#  ':"9.5 临界区","duration":167,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739875,"page":62,"from":"vupload",',
#  ':"9.6 方法1：禁用硬件中断","duration":239,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739902,"page":63,"from":"vupload",',
#  ':"9.7 方法2：基于软件的解决方案","duration":1287,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53739941,"page":64,"from":"vupload",',
#  ':"9.8 方法3：更高级的抽象","duration":905,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740121,"page":65,"from":"vupload",',
#  ':"10.1 背景","duration":152,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740174,"page":66,"from":"vupload",',
#  ':"10.2 信号量","duration":352,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740182,"page":67,"from":"vupload",',
#  ':"10.3 信号量的使用","duration":1246,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740198,"page":68,"from":"vupload",',
#  ':"10.4 信号量的实现","duration":329,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740257,"page":69,"from":"vupload",',
#  ':"10.5 管程","duration":1496,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740273,"page":70,"from":"vupload",',
#  ':"10.6 经典同步问题-1","duration":647,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740329,"page":71,"from":"vupload",',
#  ':"10.7 经典同步问题-2","duration":321,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740348,"page":72,"from":"vupload",',
#  ':"10.8 经典同步问题-3","duration":950,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740359,"page":73,"from":"vupload",',
#  ':"10.9 经典同步问题-4","duration":825,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740417,"page":74,"from":"vupload",',
#  ':"10.10 经典同步问题-5","duration":990,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740455,"page":75,"from":"vupload",',
#  ':"10.11 景点同步问题-6","duration":696,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740607,"page":76,"from":"vupload",',
#  ':"11.1 死锁问题","duration":212,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740653,"page":77,"from":"vupload",',
#  ':"11.2 系统模型","duration":1227,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740666,"page":78,"from":"vupload",',
#  ':"11.3 死锁特征","duration":317,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740806,"page":79,"from":"vupload",',
#  ':"11.4 死锁处理办法","duration":215,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740865,"page":80,"from":"vupload",',
#  ':"11.5 死锁预防和死锁避免","duration":922,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740885,"page":81,"from":"vupload",',
#  ':"11.6 银行家算法","duration":1373,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53740970,"page":82,"from":"vupload",',
#  ':"11.7 死锁检测和死锁恢复","duration":890,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741198,"page":83,"from":"vupload",',
#  ':"11.8 IPC概述","duration":482,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741267,"page":84,"from":"vupload",',
#  ':"11.9 信号、管道、消息队列和共享内存","duration":1362,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741317,"page":85,"from":"vupload",',
#  ':"12.1 文件系统：总体介绍","duration":104,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741524,"page":86,"from":"vupload",',
#  ':"12.2 基本概念","duration":120,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741546,"page":87,"from":"vupload",',
#  ':"12.3 基本概念——文件系统和文件","duration":225,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741565,"page":88,"from":"vupload",',
#  ':"12.4 基本概念——文件系统的功能","duration":161,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741593,"page":89,"from":"vupload",',
#  ':"12.5 基本概念——文件和块","duration":56,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741674,"page":90,"from":"vupload",',
#  ':"12.6 基本概念——文件描述符","duration":946,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53741761,"page":91,"from":"vupload",',
#  ':"12.7 基本概念——目录","duration":369,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53742097,"page":92,"from":"vupload",',
#  ':"12.8 基本概念——文件别名","duration":355,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53742238,"page":93,"from":"vupload",',
#  ':"12.9 基本概念——文件系统种类","duration":469,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53742341,"page":94,"from":"vupload",',
#  ':"12.10 虚拟文件系统","duration":544,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53742411,"page":95,"from":"vupload",',
#  ':"12.11 数据缓存","duration":232,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53742545,"page":96,"from":"vupload",',
#  ':"12.12 打开文件的数据结构","duration":257,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53742607,"page":97,"from":"vupload",',
#  ':"12.13 文件分配","duration":817,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53742648,"page":98,"from":"vupload",',
#  ':"12.14 空闲空间列表","duration":309,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53742742,"page":99,"from":"vupload",',
#  ':"12.15 多磁盘管理-RAID","duration":860,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53780571,"page":100,"from":"vupload",',
#  ':"12.16 磁盘调度","duration":942,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53780573,"page":101,"from":"vupload",',
#  ':"Lab0.1 实验准备1","duration":704,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53780659,"page":102,"from":"vupload",',
#  ':"Lab0.2 实验准备2","duration":1421,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53780685,"page":103,"from":"vupload",',
#  ':"Lab0.3 实验准备","duration":1897,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53780776,"page":104,"from":"vupload",',
#  ':"Lab1.1 bootloader启动ucore os","duration":1190,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53780873,"page":105,"from":"vupload",',
#  ':"Lab1.2 c函数调用的实现","duration":425,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53780918,"page":106,"from":"vupload",',
#  ':"Lab1.3 GCC内联汇编","duration":777,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53780930,"page":107,"from":"vupload",',
#  ':"Lab1.4 X86中的中断处理","duration":880,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53780965,"page":108,"from":"vupload",',
#  ':"Lab1.5 完成过程1","duration":1747,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53781015,"page":109,"from":"vupload",',
#  ':"Lab1.6 完成过程2","duration":1616,"vid":"","weblink":"","dimension":{"width":640,"height":480,"rotate":0}},{"cid":53781079,"page":110,"from":"vupload",',
#  ':"Lab2.1 X86特权级","duration":1725,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53781167,"page":111,"from":"vupload",',
#  ':"Lab2.2 x86内存管理单元MMU","duration":1490,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53781182,"page":112,"from":"vupload",',
#  ':"Lab2.3 实验实现","duration":1884,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53781199,"page":113,"from":"vupload",',
#  ':"Lab3.1","duration":1386,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53781268,"page":114,"from":"vupload",',
#  ':"Lab3.2","duration":849,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}},{"cid":53781292,"page":115,"from":"vupload",',
#  ':"Lab3.3","duration":1887,"vid":"","weblink":"","dimension":{"width":1280,"height":720,"rotate":0}}],"subtitle":{"allow_submit":false,"list":[]},"embedPlayer":"EmbedPlayer(\\"player\\", \\"\\u002F\\u002Fs1.hdslb.com\\u002Fbfs\\u002Fstatic\\u002Fplayer\\u002Fmain\\u002Fflash\\u002Fplay.swf\\", \\"cid=53736602&aid=30708793&attribute=16384\\")"},"upData":{"mid":"10787461","name":"骄傲的魂灵","approve":false,"sex":"男","rank":"10000","face":"http:\\u002F\\u002Fi2.hdslb.com\\u002Fbfs\\u002Fface\\u002F608bcb2f21c692919610ccc3ec4b58131b1597b0.jpg","DisplayRank":"0","regtime":0,"spacesta":0,"birthday":"","place":"","description":"","article":0,"attentions":[],"fans":12332,"friend":22,"attention":22,"sign":"知识传播者","level_info":{"current_level":5,"current_min":0,"current_exp":0,"next_exp":0},"pendant":{"pid":0,"name":"","image":"","expire":0},"nameplate":{"nid":6,"name":"高级搬运工","image":"http:\\u002F\\u002Fi1.hdslb.com\\u002Fbfs\\u002Fface\\u002Fa9af39ab7ed08e078c45d58dd96a6411aba1a9d3.png","image_small":"http:\\u002F\\u002Fi2.hdslb.com\\u002Fbfs\\u002Fface\\u002F46e5aae4667c72c379b46b51fac4b4426d9214e7.png","level":"高级勋章","condition":"转载视频投稿通过总数\\u003E=100"},"Official":{"role":0,"title":"","desc":""},"official_verify":{"type":-1,"desc":""},"vip":{"vipType":0,"dueRemark":"","accessStatus":0,"vipStatus":0,"vipStatusWarn":"","theme_type":0},"archiveCount":174},"staffData":[],"tags":[{"tag_id":133915,"tag_name":"清华大学","cover":"","head_cover":"","content":"","short_content":"","type":3,"state":0,"ctime":1436866637,"count":{"view":0,"use":4987,"atten":5373},"is_atten":0,"likes":1,"hates":0,"attribute":0,"liked":0,"hated":0,"showDetail":false,"showReport":false,"timeOut":null},{"tag_id":6595106,"tag_name":"操作系统原理","cover":"","head_cover":"","content":"","short_content":"","type":0,"state":0,"ctime":1521282771,"count":{"view":0,"use":9,"atten":2},"is_atten":0,"likes":1,"hates":0,"attribute":0,"liked":0,"hated":0,"showDetail":false,"showReport":false,"timeOut":null},{"tag_id":13160,"tag_name":"学习","cover":"","head_cover":"","content":"","short_content":"","type":3,"state":0,"ctime":1436866637,"count":{"view":0,"use":1187430,"atten":358444},"is_atten":0,"likes":0,"hates":0,"attribute":0,"liked":0,"hated":0,"showDetail":false,"showReport":false,"timeOut":null}],"comment":{"count":41,"list":["配套上机实验地址：\\nhttps:\\u002F\\u002Fwww.shiyanlou.com\\u002Fcourses\\u002F221\\ngithub上的课程项目：\\nhttps:\\u002F\\u002Fgithub.com\\u002Fchyyuu\\u002Fos_course_info","7.11跟7.12的内容重复了，创建进程的那个课件应该是丢了","看了三节课，做了很多笔记，听不懂，觉得自己在虐待自己"]},"related":[{"aid":59006688,"cid":102852479,"duration":100664,"pic":"http:\\u002F\\u002Fi2.hdslb.com\\u002Fbfs\\u002Farchive\\u002F457c2be8ed248f79c9df3b01edc45aad4dc8b347.jpg","title":"浙江大学-操作系统（国家级精品课）","owner":{"name":"五味666","mid":21675989},"stat":{"danmaku":103,"view":11030}},{"aid":47783076,"cid":83827537,"duration":4970,"pic":"http:\\u002F\\u002Fi2.hdslb.com\\u002Fbfs\\u002Farchive\\u002Ff73255c608737446a783392f82bb8c5480adede8.jpg","title":"【学习 | 爱情 | 浪漫】学霸的爱情故事，15岁相遇，一起追逐梦想，陪伴才是最长情的告白","owner":{"name":"lijianfex","mid":15584227},"stat":{"danmaku":3,"view":15301}},{"aid":62120450,"cid":107964696,"duration":205184,"pic":"http:\\u002F\\u002Fi1.hdslb.com\\u002Fbfs\\u002Farchive\\u002Fb8807c7429b8fe7e7ccea71b599e09a2f335e2c5.jpg","title":"清华大学-经济学原理（国家级精品课）","owner":{"name":"五味666","mid":21675989},"stat":{"danmaku":93,"view":42631}},{"aid":50757124,"cid":88861306,"duration":51504,"pic":"http:\\u002F\\u002Fi1.hdslb.com\\u002Fbfs\\u002Farchive\\u002F6583743a22a0fac88e916dd9cd09e2820947f2aa.jpg","title":"操作系统原理（考研以及想深入学习的同学强烈推荐）","owner":{"name":"情怀的歌单","mid":98569054},"stat":{"danmaku":136,"view":41299}},{"aid":28416094,"cid":49153800,"duration":57570,"pic":"http:\\u002F\\u002Fi1.hdslb.com\\u002Fbfs\\u002Farchive\\u002F758df73fe321c0251e1f7dbe2ea3ead31b27fa43.jpg","title":"【清华大学】操作系统原理·上（1-92P）","owner":{"name":"白稚卿","mid":38934450},"stat":{"danmaku":49,"view":19586}},{"aid":12169693,"cid":20063813,"duration":3756,"pic":"http:\\u002F\\u002Fi0.hd ...

# %%
mulus=[]
for mulu in mululist:
    m,i=0,0
    while m<2:
        if mulu[i]=='"':
            m+=1
        i+=1
    mulus.append(mulu[2:i-1])

# %%
mulus
# Out:
# ['1.1 课程概述',
#  '1.2 什么是操作系统',
#  '1.2 什么是操作系统',
#  '1.2 什么是操作系统',
#  '1.3 为什么学习操作系统',
#  '1.4 如何学习操作系统',
#  '1.5 操作系统实例',
#  '1.6 操作系统的历史',
#  '1.7 操作系统结构',
#  '1.8 小结',
#  '2.1 操作系统的启动',
#  '2.2 操作系统的终端、异常、和系统调用',
#  '3.1 计算机体系结构及内存分层体系',
#  '3.2 地址空间与地址生成',
#  '3.3 连续内存分配：内存碎片与分区的动态分配',
#  '3.4 连续内存分配：压缩式与交换式碎片整理',
#  '4.1 非连续内存分配：分段',
#  '4.2 非连续内存分配：分页',
#  '4.3 非连续内存分配：页表－概述、TLB',
#  '4.4 非连续内存分配：页表－二级，多级页表',
#  '4.5 非连续内存分配：页表－反向页表',
#  '5.1 虚拟内存的起因',
#  '5.2 覆盖技术',
#  '5.3 交换技术',
#  '5.4 虚存技术（上）',
#  '5.5 虚存技术（下）',
#  '6.1 最优页面置换算法',
#  '6.2 先进先出算法',
#  '6.3 最近最久未使用算法',
#  '6.4 时钟页面置换算法',
#  '6.5 二次机会法',
#  '6.6 最不常用法',
#  '6.7 Belady现象、LRU、FIFO、Clock的比较',
#  '6.8 局部页替换算法的问题、工作集模型',
#  '6.9 两个全局置换算法',
#  '6.10 抖动问题',
#  '7.1 进程的定义',
#  '7.2 进程的组成',
#  '7.3 进程的特点',
#  '7.4 进程控制结构',
#  '7.5 进程的生命期原理',
#  '7.6 进程状态变化模型',
#  '7.7 进程挂起',
#  '7.8 为什么使用线程',
#  '7.9 什么是线程',
#  '7.10 线程的实现',
#  '7.11 上下文切换',
#  '7.12 进程控制——创建进程',
#  '7.13 进程控制——加载和执行进程',
#  '7.14 进程控制——等待和终止进程',
#  '8.1 背景',
#  '8.2 调度原则',
#  '8.3 调度算法1',
#  '8.4 调度算法2',
#  '8.5 实时调度',
#  '8.6 多处理器调度与优先级反转',
#  '9.1 背景知识',
#  '9.2 一些概念part1',
#  '9.3 一些概念part2',
#  '9.4 一些概念part3',
#  '9.5 临界区',
#  '9.6 方法1：禁用硬件中断',
#  '9.7 方法2：基于软件的解决方案',
#  '9.8 方法3：更高级的抽象',
#  '10.1 背景',
#  '10.2 信号量',
#  '10.3 信号量的使用',
#  '10.4 信号量的实现',
#  '10.5 管程',
#  '10.6 经典同步问题-1',
#  '10.7 经典同步问题-2',
#  '10.8 经典同步问题-3',
#  '10.9 经典同步问题-4',
#  '10.10 经典同步问题-5',
#  '10.11 景点同步问题-6',
#  '11.1 死锁问题',
#  '11.2 系统模型',
#  '11.3 死锁特征',
#  '11.4 死锁处理办法',
#  '11.5 死锁预防和死锁避免',
#  '11.6 银行家算法',
#  '11.7 死锁检测和死锁恢复',
#  '11.8 IPC概述',
#  '11.9 信号、管道、消息队列和共享内存',
#  '12.1 文件系统：总体介绍',
#  '12.2 基本概念',
#  '12.3 基本概念——文件系统和文件',
#  '12.4 基本概念——文件系统的功能',
#  '12.5 基本概念——文件和块',
#  '12.6 基本概念——文件描述符',
#  '12.7 基本概念——目录',
#  '12.8 基本概念——文件别名',
#  '12.9 基本概念——文件系统种类',
#  '12.10 虚拟文件系统',
#  '12.11 数据缓存',
#  '12.12 打开文件的数据结构',
#  '12.13 文件分配',
#  '12.14 空闲空间列表',
#  '12.15 多磁盘管理-RAID',
#  '12.16 磁盘调度',
#  'Lab0.1 实验准备1',
#  'Lab0.2 实验准备2',
#  'Lab0.3 实验准备',
#  'Lab1.1 bootloader启动ucore os',
#  'Lab1.2 c函数调用的实现',
#  'Lab1.3 GCC内联汇编',
#  'Lab1.4 X86中的中断处理',
#  'Lab1.5 完成过程1',
#  'Lab1.6 完成过程2',
#  'Lab2.1 X86特权级',
#  'Lab2.2 x86内存管理单元MMU',
#  'Lab2.3 实验实现',
#  'Lab3.1',
#  'Lab3.2',
#  'Lab3.3']

# %%
url='https://www.bilibili.com/video/av9876107?p=2'
headers = {
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,ja;q=0.7',
        'Connection': 'keep-alive',
        # 'Referer': 'https://www.bilibili.com/video/' + str(i) + '?spm_id_from=333.338.recommend_report.3',
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
    }
content=requests.get(url, headers=headers, timeout=6).text
content_list=content.split('"part"')
mululist=[x for x in content_list if re.match(r'(.*)"duration"(.*),"vid":"","weblink":"","dimension":',x)]
mulus=[]
for mulu in mululist:
    m,i=0,0
    while m<2:
        if mulu[i]=='"':
            m+=1
        i+=1
    mulus.append(mulu[2:i-1])
mulus
# Out:
# ['0001.第1章 计算机网络概述--课程介绍',
#  '0002.第1章 计算机网络概述--局域网',
#  '0003.第1章 计算机网络概述--Intenet和广域网',
#  '0004.第1章 计算机网络概述--规划IP地址介绍MAC地址',
#  '0005.第1章 计算机网络概述--数据包和数据帧',
#  '0006.第1章 计算机网络概述--访问网站数据传输过程',
#  '0007.第1章 计算机网络概述--OSI参考模型',
#  '0008.第1章 计算机网络概述--理解OSI参考模型分层思想',
#  '0009.第1章 计算机网络概述--OSI参考模型和网络排错',
#  '0010.第1章 计算机网络概述--OSI参考模型和网络安全',
#  '0011.第1章 计算机网络概述--OSI参考模型和TCP_IP协议',
#  '0012.第1章 计算机网络概述--计算机网络性能指标1',
#  '0013.第1章 计算机网络概述-计算机网络性能指标2',
#  '0014.第2章 物理层--物理层定义的标准',
#  '0015.第2章 物理层--数据通信基础知识',
#  '0016.第2章 物理层--常用编码',
#  '0017.第2章 物理层--奈氏准则和香农公式',
#  '0018.第2章 物理层--数据通信基础知识总结',
#  '0019.第2章 物理层--物理层下面的传输介质',
#  '0020.第2章 物理层--信道复用技术',
#  '0021.第2章 物理层--数字传输系统',
#  '0022.第2章 物理层--宽带接入技术',
#  '0023.第3章 数据链路层--数据链路层基本概念',
#  '0024.第3章 数据链路层--封装成帧和透明传输',
#  '0025.第3章 数据链路层--差错检测',
#  '0026.第3章 数据链路层--点到点通信数据链路层协议PPP',
#  '0027.第3章 数据链路层--配置路由器使用PPP协议',
#  '0028.第3章 数据链路层--广播信道的数据链路层',
#  '0029.第3章 数据链路层--CSMA_CD协议技术细节',
#  '0030.第3章 数据链路层--什么是以太网',
#  '0031.第3章 数据链路层--以太网帧格式',
#  '0032.第3章 数据链路层--抓包分析数据帧格式',
#  '0033.第3章 数据链路层--使用网桥和交换机优化以太网',
#  '0034.第3章 数据链路层--查看思科交换机MAC地址表',
#  '0035.第3章 数据链路层--快速以太网和G比特以太网',
#  '0036.第4章+网络层--网络层提供的服务',
#  '0037.第4章 网络层--验证网络层功能',
#  '0038.第4章+网络层--准备发送数据',
#  '0039.第4章+网络层--发送数据的过程',
#  '0040.第4章+网络层--ARP协议',
#  '0041.第4章+网络层--ARP欺骗',
#  '0042.第4章+网络层--网络执法官和ARP防火墙',
#  '0043.第4章+网络层--ICMP协议和ping命令',
#  '0044.第4章+网络层--ping和pathping排除网络故障',
#  '0045.第4章+网络层--IGMP协议和多播组播',
#  '0046.第4章+网络层--访问多播视频节目',
#  '0047.第4章+网络层--抓包分析数据包首部',
#  '0048.第4章+网络层--数据包总长度和数据包分片',
#  '0049.第4章+网络层--抓包分析分片数据包',
#  '0050.第4章+网络层--数据包TTL和协议号',
#  '0051.第4章+网络层--使用抓包工具排除网络故障',
#  '0052.第4章+网络层--网络畅通的条件',
#  '0053.第4章+网络层--静态路由',
#  '0054.第4章+网络层--动态路由',
#  '0055.第5章+传输层--TCP和UDP的应用场景',
#  '0056.第5章+传输层--传输层协议和应用层协议之间关系',
#  '0057.第5章+传输层--服务和应用层协议之间的关系',
#  '0058.第5章+传输层--服务和端口+端口和安全',
#  '0059.第5章+传输层--传输层功能和端口范围',
#  '0060.第5章+传输层--UDP首部',
#  '0061.第5章+传输层--TCP协议概述',
#  '0062.第5章+传输层--TCP如何实现可靠传输',
#  '0063.第5章+传输层--TCP首部+端口序号确认号数据偏移',
#  '0064.第5章+传输层--抓包分析TCP首部',
#  '0065.第5章+传输层--TCP首部标记位',
#  '0066.第5章+传输层--接收窗口和发送窗口',
#  '0067.第5章+传输层--TCP滑动窗口技术实现可靠传输',
#  '0068.第5章+传输层--TCP流量控制',
#  '0069.第5章+传输层--TCP拥塞避免',
#  '0070.第5章+传输层--TCP传输连接管理',
#  '0071.第6章+应用层--什么是域名',
#  '0072.第6章+应用层--安装和配置DNS服务器',
#  '0073.第6章+应用层--安装和配置DHCP服务器',
#  '0074.第6章+应用层--跨网段配置IP地址',
#  '0075.第6章+应用层--FTP协议主动模式被动模式',
#  '0076.第6章+应用层--安装和配置FTP服务器',
#  '0077.第6章+应用层--telnet协议',
#  '0078.第6章+应用层--远程桌面协议RDP',
#  '0079.第6章+应用层--HTTP协议和网站',
#  '0080.第6章+应用层--使用Web代理服务访问网站',
#  '0081.第6章+应用层--Internet发送和接收电子邮件的过程',
#  '0082.第6章+应用层--准备邮件服务器实验环境',
#  '0083.第6章+应用层--安装和配置邮件服务器',
#  '0084.第7章+网络安全--网络安全介绍',
#  '0085.第7章+网络安全--网络安全面临的威胁',
#  '0086.第7章+网络安全--篡改和伪造',
#  '0087.第7章+网络安全--病毒和木马',
#  '0088.第7章+网络安全--对称加密',
#  '0089.第7章+网络安全--非对称加密和数字签名',
#  '0090.第7章+网络安全--证书颁发机构CA',
#  '0091.第7章+网络安全--安装CA并申请证书和邮箱',
#  '0092.第7章+网络安全--发送签名加密电子邮件',
#  '0093.第7章+网络安全--安全套接字SSL功能',
#  '0094.第7章+网络安全--配置网站使用SSL通信',
#  '0095.第7章+网络安全--介绍网络层安全IPSec']
